# %%
from Scripts import project_functions as pf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pf.load_and_process('https://raw.githubusercontent.com/data301-2020-winter1/course-project-solo_308/main/vgsales.csv?token=ARDWNGUU74PCHQDADL2ZC627WYEGS')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16286  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16287  16597                     Men in Black II: Alien Escape       GC
# 16288  16598  SCORE International Baja 1000: The Official Game      PS2
# 16289  16599                                        Know How 2       DS
# 16290  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16286  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16287  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16288  2008.0        Racing  Activision      0.00      0.00      0.00
# 16289  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16290  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16286         0.00          0.01
# 16287         0.00          0.01
# 16288         0.00          0.01
# 16289         0.00          0.01
# 16290         0.00          0.01
#
# [16291 rows x 11 columns]

# %%
# I am trying to find which platform has perfromed better worldwide
df2 = df.groupby(['Platform']).mean()
df2 = df2.sort_values('Global_Sales', ascending = False)
df2 = df2.reset_index(col_level = 1)
df2
# Out:
#    Platform          Rank         Year  NA_Sales  EU_Sales  JP_Sales  \
# 0        GB   3406.164948  1995.958763  1.171546  0.489794  0.877526
# 1       NES   1906.438776  1987.153061  1.285102  0.215816  1.006633
# 2       GEN   7037.740741  1993.037037  0.713704  0.204444  0.098889
# 3      SNES   6346.460251  1993.845188  0.256192  0.079665  0.487657
# 4       PS4   7625.562500  2015.005952  0.288095  0.368155  0.042560
# 5      X360   6639.332253  2009.879254  0.481629  0.225284  0.009968
# 6      2600   4362.844828  1982.137931  0.696379  0.041897  0.000000
# 7       PS3   6766.470859  2010.819785  0.298236  0.261097  0.060744
# 8       Wii   7697.413178  2008.962791  0.385558  0.204922  0.052930
# 9       N64   6521.863924  1998.531646  0.439589  0.129842  0.106835
# 10     XOne   7397.061033  2014.788732  0.390563  0.214319  0.001596
# 11       PS   6956.608074  1998.004205  0.281505  0.178621  0.117561
# 12      PS2   7483.601316  2004.583921  0.269356  0.156385  0.064664
# 13     WiiU   7756.237762  2013.594406  0.267972  0.169441  0.089441
# 14      3DS   9111.693387  2013.060120  0.156373  0.116814  0.194990
# 15      GBA   8734.597964  2003.175573  0.227010  0.092226  0.059237
# 16       DS   9601.487565  2008.197560  0.182323  0.091061  0.082130
# 17       GC   8617.328413  2003.400369  0.243432  0.070701  0.039373
# 18       XB   8761.047323  2003.636364  0.226725  0.074284  0.001719
# 19      SCD  10171.833333  1993.833333  0.166667  0.060000  0.075000
# 20       DC   8771.423077  1999.942308  0.104423  0.032500  0.164615
# 21       PC  11450.363539  2008.763326  0.098124  0.146429  0.000181
# 22      PSP  10414.389307  2008.721805  0.089465  0.056107  0.063400
# 23       WS   7878.833333  2000.000000  0.000000  0.000000  0.236667
# 24      SAT   9333.936416  1996.028902  0.004162  0.003121  0.186474
# 25      PSV  11449.287805  2014.024390  0.039195  0.039683  0.050878
# 26       NG  10665.666667  1994.500000  0.000000  0.000000  0.120000
# 27     TG16  12381.500000  1995.000000  0.000000  0.000000  0.080000
# 28       GG  13527.000000  1992.000000  0.000000  0.000000  0.040000
# 29      3DO  14372.666667  1994.666667  0.000000  0.000000  0.033333
# 30     PCFX  14559.000000  1996.000000  0.000000  0.000000  0.030000
#
#     Other_Sales  Global_Sales
# 0      0.084124      2.622887
# 1      0.054184      2.561939
# 2      0.032963      1.050370
# 3      0.013473      0.837029
# 4      0.129048      0.827679
# 5      0.068614      0.785737
# 6      0.007241      0.746293
# 7      0.107983      0.728029
# 8      0.061395      0.705279
# 9      0.013639      0.690538
# 10     0.055962      0.662254
# 11     0.034222      0.611766
# 12     0.089549      0.579906
# 13     0.045105      0.572448
# 14     0.025150      0.493527
# 15     0.009555      0.388830
# 16     0.028292      0.384284
# 17     0.009465      0.363727
# 18     0.010560      0.313935
# 19     0.008333      0.311667
# 20     0.005192      0.307115
# 21     0.025938      0.271535
# 22     0.034687      0.243701
# 23     0.000000      0.236667
# 24     0.000405      0.194162
# 25     0.020512      0.150244
# 26     0.000000      0.120000
# 27     0.000000      0.080000
# 28     0.000000      0.040000
# 29     0.000000      0.033333
# 30     0.000000      0.030000

# %%
fig, ax = plt.subplots(figsize=(8,12))
sns.barplot(x='Global_Sales', y= 'Platform', data = df)
plt.xlabel('Global_Sales')
# Game boy(GB) has been the best perfroming platfrom globally in terms of game sales.
# Out:
# Text(0.5, 0, 'Global_Sales')

# %%
fig, ax = plt.subplots(figsize=(8,12))
sns.barplot(x='NA_Sales', y= 'Platform', data = df)
plt.xlabel('NA_Sales')
# Nintendo Entertainment System(NES) has been the best perfroming platfrom in North America in terms of game sales.
# Out:
# Text(0.5, 0, 'NA_Sales')

# %%
fig, ax = plt.subplots(figsize=(8,12))
sns.barplot(x='EU_Sales', y= 'Platform', data = df)
plt.xlabel('EU_Sales')
# Game Boy(GB) has been the best perfroming platfrom in Europe in terms of game sales.
# Out:
# Text(0.5, 0, 'EU_Sales')

# %%
fig, ax = plt.subplots(figsize=(8,12))
sns.barplot(x='JP_Sales', y= 'Platform', data = df)
plt.xlabel('JP_Sales')
# Nintendo Entertainment System(NES) has been the best perfroming platfrom in Japan in terms of game sales.
# Out:
# Text(0.5, 0, 'JP_Sales')

# %%
'''PC has been used worldwide but yet it is not the best perfroming platform. One of the reason I think is that PC games have been facing problem with pirating. Other platform like PS, GB, NES and Xbox it is tough to pirate games.Therefore, many games company sales record are not too high for PC.'''
# Out:
# 'PC has been used worldwide but yet it is not the best perfroming platform. One of the reason I think is that PC games have been facing problem with pirating. Other platform like PS, GB, NES and Xbox it is tough to pirate games.Therefore, many games company sales record are not too high for PC.'

# %%
sns.pairplot(df)
#Japan's sale record are high overall from 1980 to 2018.
